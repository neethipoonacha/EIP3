# %% [markdown]
# <a href="https://colab.research.google.com/github/neethipoonacha/EIP3/blob/master/facerecog_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sungnam0/Face-Aging-with-CycleGAN.git
# Out:
# Cloning into 'Face-Aging-with-CycleGAN'...
# remote: Enumerating objects: 83, done.
# remote: Total 83 (delta 0), reused 0 (delta 0), pack-reused 83
# Unpacking objects: 100% (83/83), done.

# %%
# !pip install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 1.5MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.3.0
#     Uninstalling scipy-1.3.0:
#       Successfully uninstalled scipy-1.3.0
# ...

# %%
# !rm -rf Face-Aging-with-CycleGAN/checkpoint
# !python Face-Aging-with-CycleGAN/model.py dtype=/datasets/face/testB/KakaoTalk_20181212_013947907.jpg
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 08:49:25.477872 140674516035456 deprecation_wrapper.py:119] From Face-Aging-with-CycleGAN/model.py:305: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0731 08:49:25.478264 140674516035456 deprecation_wrapper.py:119] From Face-Aging-with-CycleGAN/model.py:308: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-07-31 08:49:25.484521: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2019-07-31 08:49:25.484830: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x29ffdc0 executing computations on platform Host. Devices:
# 2019-07-31 08:49:25.484869: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-07-31 08:49:25.487144: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !rm -rf Face-Aging-with-CycleGAN/checkpoint
# !python Face-Aging-with-CycleGAN/model.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 09:20:46.687582 140522443167616 deprecation_wrapper.py:119] From Face-Aging-with-CycleGAN/model.py:305: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0731 09:20:46.687964 140522443167616 deprecation_wrapper.py:119] From Face-Aging-with-CycleGAN/model.py:308: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-07-31 09:20:46.694195: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2019-07-31 09:20:46.694449: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x22b7dc0 executing computations on platform Host. Devices:
# 2019-07-31 09:20:46.694486: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-07-31 09:20:46.696915: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...
