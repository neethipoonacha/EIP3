# %% [markdown]
# <a href="https://colab.research.google.com/github/neethipoonacha/EIP3/blob/master/HorseToZebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
  https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/horse2zebra.zip \
  -O /tmp/horse2zebra.zip
# Out:
# --2019-08-24 14:19:26--  https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/horse2zebra.zip
# Resolving people.eecs.berkeley.edu (people.eecs.berkeley.edu)... 128.32.189.73
# Connecting to people.eecs.berkeley.edu (people.eecs.berkeley.edu)|128.32.189.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116867962 (111M) [application/zip]
# Saving to: ‘/tmp/horse2zebra.zip’
#
# /tmp/horse2zebra.zi 100%[===================>] 111.45M  36.3MB/s    in 3.1s
#
# 2019-08-24 14:19:30 (36.3 MB/s) - ‘/tmp/horse2zebra.zip’ saved [116867962/116867962]

# %%
import os
import zipfile

localzip = '/tmp/horse2zebra.zip'
zip_ref = zipfile.ZipFile(localzip,'r')
zip_ref.extractall('/tmp/horse2zebra/')



zip_ref.close()

# %%
horse2zebra_dir = os.path.join('/tmp/horse2zebra/trainA/horse2zebra/trainA')
print('total training rock images:', len(os.listdir(horse2zebra_dir)))

horse_files = os.listdir(horse2zebra_dir)
print(horse_files[:10])


horse2zebra_dir_Z = os.path.join('/tmp/horse2zebra/trainA/horse2zebra/trainB')
print('total training rock images:', len(os.listdir(horse2zebra_dir_Z)))

zebra_files = os.listdir(horse2zebra_dir_Z)
print(zebra_files[:10])

# %%
import os
os.environ['KERAS_BACKEND']='theano' # can choose theano, tensorflow, cntk
os.environ['THEANO_FLAGS']='floatX=float32,device=cuda,optimizer=fast_run,dnn.library_path=/usr/lib'

# %%
import keras.backend as K
if os.environ['KERAS_BACKEND'] =='theano':
    channel_axis=1
    K.set_image_data_format('channels_first')
    channel_first = True
else:
    K.set_image_data_format('channels_last')
    channel_axis=-1
    channel_first = False
# Out:
# Using Theano backend.
# ERROR (theano.gpuarray): pygpu was configured but could not be imported or is too old (version 0.7 or higher required)
# NoneType: None

# %%
from keras.models import Sequential, Model
from keras.layers import Conv2D, ZeroPadding2D, BatchNormalization, Input, Dropout
from keras.layers import Conv2DTranspose, Reshape, Activation, Cropping2D, Flatten
from keras.layers import Concatenate
from keras.layers.advanced_activations import LeakyReLU
from keras.activations import relu
from keras.initializers import RandomNormal

# %%
# Weights initializations
# bias are initailized as 0
def __conv_init(a):
    print("conv_init", a)
    k = RandomNormal(0, 0.02)(a) # for convolution kernel
    k.conv_weight = True    
    return k
conv_init = RandomNormal(0, 0.02)
gamma_init = RandomNormal(1., 0.02) # for batch normalization

# %%
# HACK speed up theano
if K._BACKEND == 'theano':
    import keras.backend.theano_backend as theano_backend
    def _preprocess_conv2d_kernel(kernel, data_format):
        #return kernel
        if hasattr(kernel, "original"):
            print("use original")
            return kernel.original
        elif hasattr(kernel, '_keras_shape'):
            s = kernel._keras_shape
            print("use reshape",s)
            kernel = kernel.reshape((s[3], s[2],s[0], s[1]))
        else:
            kernel = kernel.dimshuffle((3, 2, 0, 1))
        return kernel
    theano_backend._preprocess_conv2d_kernel = _preprocess_conv2d_kernel

# %%
# Basic discriminator
def conv2d(f, *a, **k):
    return Conv2D(f, kernel_initializer = conv_init, *a, **k)
def batchnorm():
    return BatchNormalization(momentum=0.9, axis=channel_axis, epsilon=1.01e-5,
                                   gamma_initializer = gamma_init)
def BASIC_D(nc_in, ndf, max_layers=3, use_sigmoid=True):
    """DCGAN_D(nc, ndf, max_layers=3)
       nc: channels
       ndf: filters of the first layer
       max_layers: max hidden layers
    """    
    if channel_first:
        input_a =  Input(shape=(nc_in, None, None))
    else:
        input_a = Input(shape=(None, None, nc_in))
    _ = input_a
    _ = conv2d(ndf, kernel_size=4, strides=2, padding="same", name = 'First') (_)
    _ = LeakyReLU(alpha=0.2)(_)
    
    for layer in range(1, max_layers):        
        out_feat = ndf * min(2**layer, 8)
        _ = conv2d(out_feat, kernel_size=4, strides=2, padding="same", 
                   use_bias=False, name = 'pyramid.{0}'.format(layer)             
                        ) (_)
        _ = batchnorm()(_, training=1)        
        _ = LeakyReLU(alpha=0.2)(_)
    
    out_feat = ndf*min(2**max_layers, 8)
    _ = ZeroPadding2D(1)(_)
    _ = conv2d(out_feat, kernel_size=4,  use_bias=False, name = 'pyramid_last') (_)
    _ = batchnorm()(_, training=1)
    _ = LeakyReLU(alpha=0.2)(_)
    
    # final layer
    _ = ZeroPadding2D(1)(_)
    _ = conv2d(1, kernel_size=4, name = 'final'.format(out_feat, 1), 
               activation = "sigmoid" if use_sigmoid else None) (_)    
    return Model(inputs=[input_a], outputs=_)

# %%
def UNET_G(isize, nc_in=3, nc_out=3, ngf=64, fixed_input_size=True):    
    max_nf = 8*ngf    
    def block(x, s, nf_in, use_batchnorm=True, nf_out=None, nf_next=None):
        # print("block",x,s,nf_in, use_batchnorm, nf_out, nf_next)
        assert s>=2 and s%2==0
        if nf_next is None:
            nf_next = min(nf_in*2, max_nf)
        if nf_out is None:
            nf_out = nf_in
        x = conv2d(nf_next, kernel_size=4, strides=2, use_bias=(not (use_batchnorm and s>2)),
                   padding="same", name = 'conv_{0}'.format(s)) (x)
        if s>2:
            if use_batchnorm:
                x = batchnorm()(x, training=1)
            x2 = LeakyReLU(alpha=0.2)(x)
            x2 = block(x2, s//2, nf_next)
            x = Concatenate(axis=channel_axis)([x, x2])            
        x = Activation("relu")(x)
        x = Conv2DTranspose(nf_out, kernel_size=4, strides=2, use_bias=not use_batchnorm,
                            kernel_initializer = conv_init,          
                            name = 'convt.{0}'.format(s))(x)        
        x = Cropping2D(1)(x)
        if use_batchnorm:
            x = batchnorm()(x, training=1)
        if s <=8:
            x = Dropout(0.5)(x, training=1)
        return x
    
    s = isize if fixed_input_size else None
    if channel_first:
        _ = inputs = Input(shape=(nc_in, s, s))
    else:
        _ = inputs = Input(shape=(s, s, nc_in))        
    _ = block(_, isize, nc_in, False, nf_out=nc_out, nf_next=ngf)
    _ = Activation('tanh')(_)
    return Model(inputs=inputs, outputs=[_])

# %%
nc_in = 3
nc_out = 3
ngf = 64
ndf = 64
use_lsgan = True
λ = 10 if use_lsgan else 100

loadSize = 143
imageSize = 128
batchSize = 1
lrD = 2e-4
lrG = 2e-4

# %%
netDA = BASIC_D(nc_in, ndf, use_sigmoid = not use_lsgan)
netDB = BASIC_D(nc_out, ndf, use_sigmoid = not use_lsgan)
netDA.summary()
# Out:
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 1)
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 1)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, None, None)     0
# _________________________________________________________________
# First (Conv2D)               (None, 64, None, None)    3136
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, None, None)    0
# _________________________________________________________________
# pyramid.1 (Conv2D)           (None, 128, None, None)   131072
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, None, None)   512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128, None, None)   0
# _________________________________________________________________
# pyramid.2 (Conv2D)           (None, 256, None, None)   524288
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, None, None)   1024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 256, None, None)   0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 256, None, None)   0
# _________________________________________________________________
# pyramid_last (Conv2D)        (None, 512, None, None)   2097152
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512, None, None)   2048
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 512, None, None)   0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 512, None, None)   0
# _________________________________________________________________
# final (Conv2D)               (None, 1, None, None)     8193
# =================================================================
# Total params: 2,767,425
# Trainable params: 2,765,633
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot


netGB = UNET_G(imageSize, nc_in, nc_out, ngf)
netGA = UNET_G(imageSize, nc_out, nc_in, ngf)
#SVG(model_to_dot(netG, show_shapes=True).create(prog='dot', format='svg'))
netGA.summary()
# Out:
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 256, 1024)
# use reshape (4, 4, 128, 512)
# use reshape (4, 4, 64, 256)
# use reshape (4, 4, 3, 128)
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 256, 1024)
# use reshape (4, 4, 128, 512)
# use reshape (4, 4, 64, 256)
# use reshape (4, 4, 3, 128)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 3, 128, 128)  0
# __________________________________________________________________________________________________
# conv_128 (Conv2D)               (None, 64, 64, 64)   3136        input_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 64, 64, 64)   0           conv_128[0][0]
# __________________________________________________________________________________________________
# conv_64 (Conv2D)                (None, 128, 32, 32)  131072      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 32, 32)  512         conv_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 128, 32, 32)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv_32 (Conv2D)                (None, 256, 16, 16)  524288      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 16, 16)  1024        conv_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 256, 16, 16)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 512, 8, 8)    2097152     leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 512, 8, 8)    2048        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 512, 8, 8)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 512, 4, 4)    4194304     leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 512, 4, 4)    2048        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 512, 4, 4)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 512, 2, 2)    4194304     leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 512, 2, 2)    2048        conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 512, 2, 2)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 512, 1, 1)    4194816     leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512, 1, 1)    0           conv_2[0][0]
# __________________________________________________________________________________________________
# convt.2 (Conv2DTranspose)       (None, 512, 4, 4)    4194304     activation_9[0][0]
# __________________________________________________________________________________________________
# cropping2d_8 (Cropping2D)       (None, 512, 2, 2)    0           convt.2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 512, 2, 2)    2048        cropping2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512, 2, 2)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1024, 2, 2)   0           batch_normalization_22[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1024, 2, 2)   0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# convt.4 (Conv2DTranspose)       (None, 512, 6, 6)    8388608     activation_10[0][0]
# __________________________________________________________________________________________________
# cropping2d_9 (Cropping2D)       (None, 512, 4, 4)    0           convt.4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 512, 4, 4)    2048        cropping2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512, 4, 4)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 1024, 4, 4)   0           batch_normalization_21[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1024, 4, 4)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# convt.8 (Conv2DTranspose)       (None, 512, 10, 10)  8388608     activation_11[0][0]
# __________________________________________________________________________________________________
# cropping2d_10 (Cropping2D)      (None, 512, 8, 8)    0           convt.8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 512, 8, 8)    2048        cropping2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512, 8, 8)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 1024, 8, 8)   0           batch_normalization_20[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1024, 8, 8)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# convt.16 (Conv2DTranspose)      (None, 256, 18, 18)  4194304     activation_12[0][0]
# __________________________________________________________________________________________________
# cropping2d_11 (Cropping2D)      (None, 256, 16, 16)  0           convt.16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 16, 16)  1024        cropping2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 512, 16, 16)  0           batch_normalization_19[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 512, 16, 16)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# convt.32 (Conv2DTranspose)      (None, 128, 34, 34)  1048576     activation_13[0][0]
# __________________________________________________________________________________________________
# cropping2d_12 (Cropping2D)      (None, 128, 32, 32)  0           convt.32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 32, 32)  512         cropping2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 32, 32)  0           batch_normalization_18[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 256, 32, 32)  0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# convt.64 (Conv2DTranspose)      (None, 64, 66, 66)   262144      activation_14[0][0]
# __________________________________________________________________________________________________
# cropping2d_13 (Cropping2D)      (None, 64, 64, 64)   0           convt.64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 64)   256         cropping2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 128, 64, 64)  0           conv_128[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 64, 64)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# convt.128 (Conv2DTranspose)     (None, 3, 130, 130)  6147        activation_15[0][0]
# __________________________________________________________________________________________________
# cropping2d_14 (Cropping2D)      (None, 3, 128, 128)  0           convt.128[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 3, 128, 128)  0           cropping2d_14[0][0]
# ==================================================================================================
# Total params: 41,837,379
# Trainable params: 41,829,571
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
from keras.optimizers import RMSprop, SGD, Adam

# %%
if use_lsgan:
    loss_fn = lambda output, target : K.mean(K.abs(K.square(output-target)))
else:
    loss_fn = lambda output, target : -K.mean(K.log(output+1e-12)*target+K.log(1-output+1e-12)*(1-target))

def cycle_variables(netG1, netG2):
    real_input = netG1.inputs[0]
    fake_output = netG1.outputs[0]
    rec_input = netG2([fake_output])
    fn_generate = K.function([real_input], [fake_output, rec_input])
    return real_input, fake_output, rec_input, fn_generate

real_A, fake_B, rec_A, cycleA_generate = cycle_variables(netGB, netGA)
real_B, fake_A, rec_B, cycleB_generate = cycle_variables(netGA, netGB)
# Out:
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 256, 1024)
# use reshape (4, 4, 128, 512)
# use reshape (4, 4, 64, 256)
# use reshape (4, 4, 3, 128)
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 512)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 512, 1024)
# use reshape (4, 4, 256, 1024)
# use reshape (4, 4, 128, 512)
# use reshape (4, 4, 64, 256)
# use reshape (4, 4, 3, 128)

# %%
def D_loss(netD, real, fake, rec):
    output_real = netD([real])
    output_fake = netD([fake])
    loss_D_real = loss_fn(output_real, K.ones_like(output_real))
    loss_D_fake = loss_fn(output_fake, K.zeros_like(output_fake))
    loss_G = loss_fn(output_fake, K.ones_like(output_fake))
    loss_D = loss_D_real+loss_D_fake
    loss_cyc = K.mean(K.abs(rec-real))
    return loss_D, loss_G, loss_cyc

loss_DA, loss_GA, loss_cycA = D_loss(netDA, real_A, fake_A, rec_A)
loss_DB, loss_GB, loss_cycB = D_loss(netDB, real_B, fake_B, rec_B)
loss_cyc = loss_cycA+loss_cycB
# Out:
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 1)
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 1)
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 1)
# use reshape (4, 4, 3, 64)
# use reshape (4, 4, 64, 128)
# use reshape (4, 4, 128, 256)
# use reshape (4, 4, 256, 512)
# use reshape (4, 4, 512, 1)

# %%
loss_G = loss_GA+loss_GB+λ*loss_cyc
loss_D = loss_DA+loss_DB

weightsD = netDA.trainable_weights + netDB.trainable_weights
weightsG = netGA.trainable_weights + netGB.trainable_weights

training_updates = Adam(lr=lrD, beta_1=0.5).get_updates(weightsD,[],loss_D)
netD_train = K.function([real_A, real_B],[loss_DA/2, loss_DB/2], training_updates)
training_updates = Adam(lr=lrG, beta_1=0.5).get_updates(weightsG,[], loss_G)
netG_train = K.function([real_A, real_B], [loss_GA, loss_GB, loss_cyc], training_updates)

# %%
from PIL import Image
import numpy as np
import glob
from random import randint, shuffle

def load_data(file_pattern):
    print('file_pattern',glob.glob(file_pattern))
    return glob.glob(file_pattern)

def read_image(fn):
    im = Image.open(fn).convert('RGB')
    print(im)
    im = im.resize( (loadSize, loadSize), Image.BILINEAR )
    arr = np.array(im)/255*2-1
    w1,w2 = (loadSize-imageSize)//2,(loadSize+imageSize)//2
    h1,h2 = w1,w2
    img = arr[h1:h2, w1:w2, :]
    if randint(0,1):
        img=img[:,::-1]
    if channel_first:        
        img = np.moveaxis(img, 2, 0)
    return img

#data = "edges2shoes"
data = "horse2zebra"
train_A = load_data('/tmp/horse2zebra/trainA/horse2zebra/trainA/*.jpg'.format(data))
train_B = load_data('/tmp/horse2zebra/trainA/horse2zebra/trainB/*.jpg'.format(data))
print("len(train_A)",len(train_A))
print("len(train_B)",len(train_B))

assert len(train_A) and len(train_B)
# Out:
# file_pattern ['/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1337.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4117.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_6873.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1872.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_541.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_509.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2703.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4771.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4009.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_108.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_558.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1003.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_5292.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1001.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_3548.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2226.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1194.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_6335.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_411.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2548.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2779.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_5374.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1389.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4965.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_718.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_3424.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1347.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_5156.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_6978.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1458.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1025.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_3182.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1155.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_697.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1354.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_616.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_5857.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2684.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1602.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_8639.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2019.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4123.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1405.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1904.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4529.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4602.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2741.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1478.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1348.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_5674.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4312.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_249.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_2139.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_7305.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4159.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4711.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_4402.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_879.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_86.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_1498.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainA/n02381460_73.jpg', '/tmp/horse2zebra/trainA/horse2zebr ...
# file_pattern ['/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_5711.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_602.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2571.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1551.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2005.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_7261.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2876.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_8793.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2732.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_3043.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_161.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_4704.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_328.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_932.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_3509.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_4496.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_644.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_6631.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_37.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_886.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1459.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_11.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_4027.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1095.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_5527.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1869.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2405.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2758.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1378.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_8158.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_115.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_744.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_704.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_3654.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2837.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_733.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_468.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_6159.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_4218.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2743.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_333.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_8696.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_3026.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2187.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_6757.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2921.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_3878.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_3221.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2811.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_254.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_3872.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_2848.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_10461.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1532.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_178.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_4259.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1852.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_11041.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_9965.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_6866.jpg', '/tmp/horse2zebra/trainA/horse2zebra/trainB/n02391049_1135.jpg', '/tmp/horse2zebra/trainA/horse2zebra/ ...
# len(train_A) 1067
# len(train_B) 1334

# %%
def minibatch(data, batchsize):
    length = len(data)
    epoch = i = 0
    tmpsize = None    
    while True:
        size = tmpsize if tmpsize else batchsize
        if i+size > length:
            shuffle(data)
            i = 0
            epoch+=1 
        
        rtn = [read_image(data[j]) 
        for j in range(i,i+size)]
        #print("ith value --->",i)
        #print("jth value --->",j)
        i+=size
        tmpsize = yield epoch, np.float32(rtn)       

def minibatchAB(dataA, dataB, batchsize):
    batchA=minibatch(dataA, batchsize)
    batchB=minibatch(dataB, batchsize)
    tmpsize = None    
    while True:        
        ep1, A = batchA.send(tmpsize)
        ep2, B = batchB.send(tmpsize)
        tmpsize = yield max(ep1, ep2), A, B

# %%
from IPython.display import display
def showX(X, rows=1):
    assert X.shape[0]%rows == 0
    int_X = ( (X+1)/2*255).clip(0,255).astype('uint8')
    if channel_first:
        int_X = np.moveaxis(int_X.reshape(-1,3,imageSize,imageSize), 1, 3)
    else:
        int_X = int_X.reshape(-1,imageSize,imageSize, 3)
    int_X = int_X.reshape(rows, -1, imageSize, imageSize,3).swapaxes(1,2).reshape(rows*imageSize,-1, 3)
    display(Image.fromarray(int_X))

# %%
train_batch = minibatchAB(train_A, train_B, 6)
print("TRAIN BATCHHHHH",train_batch)

_,A, B = next(train_batch)
showX(A)
showX(B)
del train_batch, A, B
# Out:
# TRAIN BATCHHHHH <generator object minibatchAB at 0x7faec5c978e0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBE10>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBEF0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBEB8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBE80>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBF28>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBF60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBE10>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBEF0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBEB8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBE80>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBF28>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5CCBF60>
# <PIL.Image.Image image mode=RGB size=768x128 at 0x7FAEC5CCBF60>
# <PIL.Image.Image image mode=RGB size=768x128 at 0x7FAEBE830F60>

# %%
def showG(A,B):
    assert A.shape==B.shape
    def G(fn_generate, X):
        r = np.array([fn_generate([X[i:i+1]]) for i in range(X.shape[0])])
        return r.swapaxes(0,1)[:,:,0]        
    rA = G(cycleA_generate, A)
    rB = G(cycleB_generate, B)
    arr = np.concatenate([A,B,rA[0],rB[0],rA[1],rB[1]])
    showX(arr, 3)

# %%
import time
from IPython.display import clear_output
t0 = time.time()
niter = 150
gen_iterations = 0
epoch = 0
errCyc_sum = errGA_sum = errGB_sum = errDA_sum = errDB_sum = 0

display_iters = 50
#val_batch = minibatch(valAB, 6, direction)
train_batch = minibatchAB(train_A, train_B, batchSize)

while epoch < niter: 
    epoch, A, B = next(train_batch)        
    errDA, errDB  = netD_train([A, B])
    errDA_sum +=errDA
    errDB_sum +=errDB

    # epoch, trainA, trainB = next(train_batch)
    errGA, errGB, errCyc = netG_train([A, B])
    errGA_sum += errGA
    errGB_sum += errGB
    errCyc_sum += errCyc
    gen_iterations+=1
    if gen_iterations%display_iters==0:
        #if gen_iterations%(5*display_iters)==0:
        clear_output()
        print('[%d/%d][%d] Loss_D: %f %f Loss_G: %f %f loss_cyc %f'
        % (epoch, niter, gen_iterations, errDA_sum/display_iters, errDB_sum/display_iters,
           errGA_sum/display_iters, errGB_sum/display_iters, 
           errCyc_sum/display_iters), time.time()-t0)
        _, A, B = train_batch.send(4)
        showG(A,B)        
        errCyc_sum = errGA_sum = errGB_sum = errDA_sum = errDB_sum = 0
# Out:
# [1/150][1600] Loss_D: 0.276636 0.242061 Loss_G: 0.385076 0.498264 loss_cyc 0.238423 10647.494086503983
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=1024x384 at 0x7FAEC5CCBA58>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEC5D84208>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAEBE830F60>
